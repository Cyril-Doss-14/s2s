# %%
pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#                                               0.0/8.1 MB ? eta -:--:--
#      ---                                      0.8/8.1 MB 16.3 MB/s eta 0:00:01
#      -------                                  1.5/8.1 MB 16.1 MB/s eta 0:00:01
#      ------------                             2.5/8.1 MB 17.7 MB/s eta 0:00:01
#      ----------------                         3.3/8.1 MB 17.7 MB/s eta 0:00:01
#      --------------------                     4.2/8.1 MB 18.1 MB/s eta 0:00:01
#      ------------------------                 5.0/8.1 MB 17.6 MB/s eta 0:00:01
#      ---------------------------              5.6/8.1 MB 17.0 MB/s eta 0:00:01
#      -------------------------------          6.4/8.1 MB 17.0 MB/s eta 0:00:01
#      -----------------------------------      7.1/8.1 MB 16.9 MB/s eta 0:00:01
#      --------------------------------------   7.8/8.1 MB 16.5 MB/s eta 0:00:01
# ...

# %%
import streamlit as st
from tensorflow.keras.models import load_model
import cv2
import numpy as np

model = load_model('model_with_regularization.keras')

def main():
    st.title("Sign Language Prediction")
    st.write("Upload an image of a hand gesture for prediction")

    uploaded_file = st.file_uploader("Choose an image...", type=["jpg", "png"])

    if uploaded_file is not None:
        image = cv2.imread(uploaded_file)
        image = cv2.resize(image, (100, 100))
        image = image / 255.0
        image = np.expand_dims(image, axis=0)

        prediction = model.predict(image)
        class_index = np.argmax(prediction)
        confidence = prediction[0][class_index]

        st.image(uploaded_file, caption='Uploaded Image.', use_column_width=True)
        st.write(f"Prediction: Class {class_index}, Confidence: {confidence:.2f}")

if __name__ == "__main__":
    main()
# Out:
# 2023-08-28 23:38:06.039
# ...
#   command:
#
#     streamlit run C:\ProgramData\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
